# %% [markdown]
# <a href="https://colab.research.google.com/github/joharika12/AI-goal-navigator/blob/main/hugging_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://huggingface.co/spaces/forbiddensoul90/PhalAI
# Out:
# Cloning into 'PhalAI'...
# remote: Enumerating objects: 378, done.
# remote: Total 378 (delta 0), reused 0 (delta 0), pack-reused 378 (from 1)
# Receiving objects: 100% (378/378), 840.15 KiB | 15.56 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# %cd PhalAI
# Out:
# /content/PhalAI

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 85.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 117.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 95.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !ls
# Out:
# PhalAI	sample_data

# %%
# !ls -la
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Jun  9 04:12 .
# drwxr-xr-x 1 root root 4096 Jun  9 04:07 ..
# drwxr-xr-x 4 root root 4096 Jun  4 13:32 .config
# drwxr-xr-x 3 root root 4096 Jun  9 04:12 PhalAI
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data

# %%
# %cd PhalAI
# Out:
# /content/PhalAI

# %%
# !ls -la
# Out:
# total 91580
# drwxr-xr-x 3 root root     4096 Jun  9 04:12 .
# drwxr-xr-x 1 root root     4096 Jun  9 04:12 ..
# -rw-r--r-- 1 root root     9861 Jun  9 04:12 app.py
# -rw-r--r-- 1 root root    12330 Jun  9 04:12 back.py
# -rw-r--r-- 1 root root    41240 Jun  9 04:12 chat_history.txt
# -rw-r--r-- 1 root root 93672967 Jun  9 04:12 faiss_db.pkl
# drwxr-xr-x 9 root root     4096 Jun  9 04:12 .git
# -rw-r--r-- 1 root root     1519 Jun  9 04:12 .gitattributes
# -rw-r--r-- 1 root root      252 Jun  9 04:12 README.md
# -rw-r--r-- 1 root root      157 Jun  9 04:12 requirements.txt
# -rw-r--r-- 1 root root      932 Jun  9 04:12 user_data.json

# %%
# !cat requirements.txt
# Out:
# pandas
# numpy
# torch
# sentence-transformers
# langchain
# langchain-community
# langchain_groq
# google-generativeai
# dataclasses
# faiss-cpu
# streamlit
# pillow

# %%
# !grep -n "API" app.py

# %%
# !streamlit run app.py
# Out:
# ...
#
# 2026-06-09 04:21:01.601 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.237.187.206:8501
#
#   Stopping...
#   Stopping...
